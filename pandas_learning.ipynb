# %%
import pandas as pd
import numpy as np

df: pd.DataFrame = pd.read_csv("datasets/organizations.csv", index_col="Index")  # type: ignore

print(df.loc[df["Number of employees"] > 9000, ["Name"]])

floored_means: np.ndarray = np.floor(df.mean(numeric_only=True))
print(floored_means.astype(int))
# Out:
#                              Name
# Index
# 10                     Gaines Inc
# 12                   Crane-Clarke
# 14                    Glover-Pope
# 38                    Cuevas-Moss
# 41                     Arroyo Inc
# 48     Wallace, Madden and Morris
# 50                   Gonzales Ltd
# 62                     Soto Group
# 64                      Riley Ltd
# Founded                1995.0
# Number of employees    4964.0
# dtype: float64
